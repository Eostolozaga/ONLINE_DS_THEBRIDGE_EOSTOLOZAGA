# %% [markdown]
# <a href="https://colab.research.google.com/github/Eostolozaga/ONLINE_DS_THEBRIDGE_EOSTOLOZAGA/blob/main/Parte_6_Ejercicio_POO_DS_01_02_02_N07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![TheBridge_logo_RGB_color.jpg](attachment:TheBridge_logo_RGB_color.jpg)

# %% [markdown]
# ![ejercicios.png](attachment:ejercicios.png)

# %% [markdown]
# # Ejercicios Clases y Objetos

# %% [markdown]
# ## Ejercicio 1
# Somos una empresa que tiene varias tiendas de electrodomesticos. Necesitamos un programa para manejar las tiendas, ver las ventas que han tenido, cuántos empleados hay, etc... Para ello vamos a modelizar la tienda en una clase, que tendrá las siguientes características:
# * Nombre clase: "Tienda"
# * Atributos comunes:
#     * Tipo: "Electrodomésticos"
#     * Abierta: True
# * Atributos propios de cada tienda:
#     * Nombre - String
#     * Dirección - String
#     * Número de empleados - int
#     * Ventas ultimos 3 meses - Lista de 3 numeros
# * Método para calcular las ventas de todos los meses, que devuelva un numero con todas las ventas.
# * Método que calcula la media de ventas de los ultimos meses, por empleado
# * Método que devuelve en un string el nombre de la tienda, junto con su dirección.
# * Método que obtiene las ventas del último mes.
# * Método para dar una proyección de las ventas en caso de haber invertido X dinero en marketing en esa tienda. Siendo X el parámetro de entrada. Si X es menor de 1000, las ventas de los ultimos 3 meses hubiesen sido de (1.2 x ventas), si es mayor o igual de 1000, las ventas hubiesen sido de (1.5 x venta). El método reescribe el atributo de ventas en los últimos 3 meses, y además devuelve las ventas con el aumento.
#
# Se pide:
# 1. Implementar la clase "Tienda"
# 2. Crear tres tiendas con datos inventados
# 3. Comprueba en al menos una de ellas, todo lo implementado en la clase tienda (sus atributos, media de ventas, ventas/empleado...)
# 3. Calcular las ventas del último mes de todas las tiendas. Para ello usa el bucle `for`
# 4. Imprime por pantalla los nombres de las tiendas cuya dirección lleve el string "Avenida"
# 5. Seguro que ya has hecho este apartado... Documenta la clase :)

# %%
class Tienda:
  tipo = "Electrodomésticos"
  abierta = True
  def __init__(self, nombre, direccion, num_empleados, ventas_ultimos_3_meses):
    self.nombre = nombre
    self.direccion = direccion
    self.num_empleados = num_empleados
    self.ventas_ultimos_3_meses = ventas_ultimos_3_meses

  def ventas_totales(self):
    return sum(self.ventas_ultimos_3_meses)

  def media_ventas_por_empleado(self):
    return self.ventas_totales() / self.num_empleados

  def nombre_direccion(self):
    return f"{self.nombre} - {self.direccion}"

  def ventas_ultimo_mes(self):
    return self.ventas_ultimos_3_meses[-1]

  def proyeccion_ventas(self, inversion_marketing):
    if inversion_marketing < 1000:
      aumento = 1.2
    else:
      aumento = 1.5

    nuevas_ventas = [venta * aumento
for venta in
self.ventas_ultimos_3_meses]

    self.ventas_ultimos_3_meses = nuevas_ventas

    return nuevas_ventas

# %%
tienda1 = Tienda(nombre = "La casa del electricista",direccion = "Calle Velazquez 9", num_empleados = 8, ventas_ultimos_3_meses = [10000, 12000, 11000])
tienda2 = Tienda(nombre = "Ibertecno",direccion = " Avenida Portugalete", num_empleados = 4, ventas_ultimos_3_meses = [5000, 6200, 4000])
tienda3 = Tienda(nombre = "Electrofake",direccion = "Bilbao", num_empleados = 25, ventas_ultimos_3_meses = [25000, 37500, 31600])

print(tienda1.nombre)
print(tienda1.direccion)
print(tienda1.num_empleados)
print(tienda1.ventas_ultimos_3_meses)
print(tienda1.tipo)
print(tienda1.abierta)
print("Ventas totales: ",tienda1.ventas_totales())
print("Media de ventas por empleado: ", tienda1.media_ventas_por_empleado())
print("Nombre y direcciíon",tienda1.nombre_direccion())
print("Ventas del último mes",tienda1.ventas_ultimo_mes())
print("Ventas con marketing(1500€: ",tienda1.proyeccion_ventas(1500))
print("Ventas actualizadas: ",tienda1.ventas_ultimos_3_meses)
# Out:
# La casa del electricista
# Calle Velazquez 9
# 8
# [10000, 12000, 11000]
# Electrodomésticos
# True
# Ventas totales:  33000
# Media de ventas por empleado:  4125.0
# Nombre y direcciíon La casa del electricista - Calle Velazquez 9
# Ventas del último mes 11000
# Ventas con marketing(1500€:  [15000.0, 18000.0, 16500.0]
# Ventas actualizadas:  [15000.0, 18000.0, 16500.0]

# %%
tiendas = [tienda1,tienda2,tienda3]

for tienda in tiendas:
  print(f"Último mes de {tienda.nombre}: {tienda.ventas_ultimo_mes()}")
# Out:
# Último mes de La casa del electricista: 16500.0
# Último mes de Ibertecno: 4000
# Último mes de Electrofake: 31600

# %%
for tienda in tiendas:
  if "Avenida" in tienda.direccion:
    print(tienda.nombre)
# Out:
# Ibertecno

# %% [markdown]
# ## Ejercicio 2
# En este ejercicio vamos a implementar una clase *Perro* en Python. La clase tiene las siguientes características:
# * Cosas que sabemos seguro que tiene un perro
#     * Tiene 4 patas
#     * 2 orejas
#     * 2 ojos
#     * Una velocidad de 0. Por defecto, el perro está parado
# * Cuando se inicialice:
#     * El perro será de una determinada raza
#     * Por defecto tendrá pelo "Marrón", a no ser que se diga lo contrario.
#     * Por defecto no tendrá dueño, a no ser que se diga lo contrario.
#
# * Dispondrá también de un método llamado andar, que tiene un argumento de entrada (aumento_velocidad). Este valor se le sumará a la velocidad que ya llevaba el perro.
# * Necesita otro método (parar), donde pondremos la velocidad a 0.
# * Otro método llamado "ladrar", que tendrá un argumento de entrada, y la salida será el siguiente string: "GUAU!" + el argumento de entrada.
#
#
# Se pide:
# * Implementa la clase *Perro*
# * Crea un objeto de tipo *Perro*, sin dueño
# * Comprueba que están bien todos sus atributos
# * Prueba que ande, y comprueba su velocidad
# * Páralo
# * Documenta la clase *Perro*

# %%
class Perro :
  def __init__(self,raza,pelo = "Marron",dueño = None):
    self.patas = 4
    self.orejas = 2
    self.ojos = 2
    self.velocidad = 0.0
    self.raza = raza
    self.pelo = pelo
    self.dueño = dueño

mi_perro = Perro("Pincher enano")

print("Patas: ",mi_perro.patas)
print("Orejas: ",mi_perro.orejas)
print("Ojos: ",mi_perro.ojos)
print("Velocidad: ",mi_perro.velocidad)
print("Raza: ",mi_perro.raza)
print("Pelo: ",mi_perro.pelo)
print("Dueño: ",mi_perro.dueño)

def andar(self,aumento_velocidad):
  self.velocidad += aumento_velocidad

def parar(self):
  self.velocidad = 0.0

def ladrar(self,texto):
  return "GUAU!" + texto

Perro.andar = andar
Perro.parar = parar
Perro.ladrar = ladrar
# Out:
# Patas:  4
# Orejas:  2
# Ojos:  2
# Velocidad:  0.0
# Raza:  Pincher enano
# Pelo:  Marron
# Dueño:  None

# %%
mi_perro.andar(6.0)
print("Velocidad después de andar: ",mi_perro.velocidad)

mi_perro.parar()
print("Velocidad despues de parar: ",mi_perro.velocidad)

print(mi_perro.ladrar("Ejercicio resuelto!"))
# Out:
# Velocidad después de andar:  6.0
# Velocidad despues de parar:  0.0
# GUAU!Ejercicio resuelto!
