# %% [markdown]
# <a href="https://colab.research.google.com/github/Eostolozaga/ONLINE_DS_THEBRIDGE_EOSTOLOZAGA/blob/main/Parte%205%20ejercicio%202%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![TheBridge_logo_RGB_color.jpg](attachment:TheBridge_logo_RGB_color.jpg)

# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# ## EJERCICIOS PYTHON BASICO 3:
# ## Operaciones matemáticas, comparación y booleanas

# %% [markdown]
# Completa los siguiente ejercicios, la solución completa a los mismos se publicarán en el repo del curso a lo largo del sprint. En algunos ejercicios se muestra la solución final, para que puedas comprobar que lo has hecho bien, pero lo importante es el código que generes. ¡Vaaamos, a ello...!

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
#
# ## Ejercicio 1
# Tenemos las siguientes variables:
#
# ```Python
# A = 4
# B = "Text"
# C = 4.1
# ```
#
# Comprueba:
# 1. Si A y B son equivalentes
# 2. Si A y C NO son equivalentes
# 3. Si A es mayor que C
# 4. Si C es menor o igual que A
# 5. Si B NO es equivalente a C

# %%
A = 4
B = "Text"
C = 4.1

A == B , A != C, A > C, C <= A,  B != C
# Out:
# (False, True, False, False, True)

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 2
# Crea un programa donde se recojan dos inputs del usuario, y el output del programa sea si esos inputs son iguales o no

# %%
input1 = input("Dime algo ")
input2 = input("Dime algo más ")

if input1 == input2:
    print(" Son iguales")
else:
    print(" No son iguales")
# Out:
# Dime algo 10
# Dime algo más 10
#  Son iguales

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 3
# Mismo programa que en 2, pero en esta ocasión tienen que ser tres inputs y dos salidas. Una de las salidas que nos indique si todos son iguales, y la otra si al menos dos inputs sí que lo son

# %%
input1 = input("Dime algo ")
input2 = input("Dime algo más ")
input3 = input("Dime una última cosa ")

if input1 == input2 == input3:
    print(" Todos son iguales")
else:
    print("No son todas iguales")
if (input1 == input2) or (input1 == input3) or (input2 == input3):
    print("Al menos dos son iguales")
else:
    print("No son iguales")
# Out:
# Dime algo Hola
# Dime algo más Hola
# Dime una última cosa Adios
# No son todas iguales
# Al menos dos son iguales

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 4
# Razona sin ejecutar código el output que obtendremos de las siguientes sentencias
# 1. True and True and False
# 2. not ((True or False) and (True or False))
# 3. (False or False or False or True) and False
# 4. not False and True and not True

# %% [markdown]
# 1. #Tenemos True y True que es True y por otro lado True y False que es False. Asi que al tener 1 False debido a que estamos usando "and" con solo tener un False la respuesta es **False**
#
# 2.Individualmente el resultado de True or False es True debido a que con "or" nos vale con que uno de los dos sea True, no obstante, el "not" condiciona que la función sea **False**
#
# 3. En este caso la parte de dentro del paréntesis al ser "or" y disponer de un True sería True. No obstante fuera de ello tenemos un "and" y False que condiciona el resultado a **False**
#
# 4. En este último caso tanto el "not False" como el "and True" dan de resultado True, sin embargo, la tercera parte hace referencia a "not True" por lo que una vez más tendríamos un False y ese único False condiciona toda la cadena por lo que el resultado una vez más es **False**
