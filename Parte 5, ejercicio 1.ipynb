# %% [markdown]
# <a href="https://colab.research.google.com/github/Eostolozaga/ONLINE_DS_THEBRIDGE_EOSTOLOZAGA/blob/main/Parte%205%2C%20ejercicio%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![TheBridge_logo_RGB_color.jpg](attachment:TheBridge_logo_RGB_color.jpg)

# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# ## EJERCICIOS PYTHON BASICO 2:
# ## Tipos y conversión de tipos

# %% [markdown]
# Completa los siguiente ejercicios, la solución a los mismos se publicarán en el repo del curso a lo largo del sprint

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 1
#
# 1. Crea dos variables numericas: un `int` y un `float`
# 2. Comprueba sus tipos
# 3. Sumalas en otra nueva
# 4. ¿De qué tipo es la nueva variable?
# 5. Elimina las dos primeras variables creadas

# %%
variable_num = 5
variable_num2 = 5.5
print(type(variable_num))
print(type(variable_num2))
variable_num3 = variable_num + variable_num2
print(type(variable_num3))
del variable_num
del variable_num2
# Out:
# <class 'int'>
# <class 'float'>
# <class 'float'>

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 2
# Escribe un programa para pasar de grados a radianes. Hay que usar `input`. Recuerda que la conversión se realiza mediante
#
# radianes = grados*(pi/180)

# %%
grados = int(input("Dime la cantidad de grados que quieres pasar a radianes"))
pi = 3.14
radianes = grados*(pi/180)
print("Los grados introducidos equivalen a ", radianes, "radianes")
# Out:
# Dime la cantidad de grados que quieres pasar a radianes10
# Los grados introducidos equivalen a  0.17444444444444446 radianes

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 3
# Escribe un programa que calcule el area de un paralelogramo (base x altura). También con `input`

# %%
base = int(input("Dime la base del paralelogramo"))
altura = int(input("Dime la altura del paralelogramo"))
area = base * altura
print("El area del paralelogramo es",(area))
# Out:
# Dime la base del paralelogramo10
# Dime la altura del paralelogramo20
# El area del paralelogramo es 200

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 4
# Escribe un programa que calcule el area de un paralelogramo (base x altura). También con `input`. En este caso debe ser capaz de admitir valores reales, con decimales, para base y altura en español. (PISTA: Recuerda que tendrás que hacer uso del método replace)

# %%
base_real = float(input("Dime la base del paralelogramo"))
altura_real = float(input("Dime la altura del paralelogramo"))
area_real = base_real * altura_real
print("El area del paralelogramo es",(area_real))
# Out:
# Dime la base del paralelogramo5.45
# Dime la altura del paralelogramo6.42
# El area del paralelogramo es 34.989

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 5
# Complete el siguiente código para solicitar al usuario su nombre y su edad. Luego, calcule en qué año nació el usuario y muestre el resultado.

# %%
nombre = str(input("¿Cuál es tu nombre? "))
edad = int(input("¿Cuál es tu edad? "))
año_actual = 2026  # Puedes cambiarlo según el año en curso
año_nacimiento = año_actual - edad

print(f"{nombre}, naciste en el año {año_nacimiento}.")
# Out:
# ¿Cuál es tu nombre? Eneko
# ¿Cuál es tu edad? 31
# Eneko, naciste en el año 1995.
